# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
from torch.autograd import Variable
from numba import cuda
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from PIL import Image
from matplotlib.ticker import FormatStrFormatter
from collections import OrderedDict
import sys,os
import pwd
import math
import getpass
import json
from matplotlib.ticker import FormatStrFormatter

# %%
#tss_username = pwd.getpwuid(os.getuid()).pw_name
#tss_password = getpass.getpass('Please enter your TSS password: ')

#os.environ['http_proxy']  = 'http://{}:{}@proxy.muc:8080/'.format(tss_username, tss_password)
#os.environ['https_proxy'] = os.environ['http_proxy']
#os.environ['no_proxy'] = 'localhost,127.0.0.1,.muc,.bmwgroup.net'

#print(os.environ.get('http_proxy'))
 
# # show all Environment Variables
#print(os.environ)

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
print ("You are in Directory:", os.getcwd())
#data_dir = input("Please Input the data Directory:")
#if data_dir =="":
data_dir = "/home/workspace/aipnd-project/flowers"
print("Input Directory is set to:", data_dir)

train_dir = data_dir + "/train" 
valid_dir = data_dir + "/valid"
test_dir = data_dir + "/test"
# Out:
# You are in Directory: /home/workspace/aipnd-project
# Input Directory is set to: /home/workspace/aipnd-project/flowers

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])])

validation_transforms = transforms.Compose([transforms.Resize(256),
                                            transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406], 
                                                                 [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
validation_data = datasets.ImageFolder(valid_dir, transform=validation_transforms)
test_data = datasets.ImageFolder(test_dir ,transform = test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
vloader = torch.utils.data.DataLoader(validation_data, batch_size =64,shuffle = True)
testloader = torch.utils.data.DataLoader(test_data, batch_size = 64)

print ("Classes in Trainloader:", (len(trainloader)))
print("Number of Pictures:", len(trainloader.dataset))
train_iter = iter(testloader)
images, labels = train_iter.next()
print('images shape on batch size = {}'.format(images.size()))
print('labels shape on batch size = {}'.format(labels.size()))
# Out:
# Classes in Trainloader: 103
# Number of Pictures: 6552
# images shape on batch size = torch.Size([64, 3, 224, 224])
# labels shape on batch size = torch.Size([64])

# %%
import json
category_names = "/home/workspace/aipnd-project/cat_to_name.json"
print("category Directory is set to:", category_names)
with open(category_names, "r") as f:
    cat_to_name = json.load(f)
# Out:
# category Directory is set to: /home/workspace/aipnd-project/cat_to_name.json

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
structures = {"vgg16":25088,
              "densenet121" : 1024,
              "alexnet" : 9216 }

# %%
def nn_setup(structure='vgg16',dropout=0.6, hidden_units = 5000, learning_rate = 0.001):
    
    # Modell zuweisen, wird keines übergeben wird vgg16 verwendet. Bei falscher Eingabe wird Alexnet verwendet.
    if structure == 'vgg16':
        model = models.vgg16(pretrained=True)        
    elif structure == 'densenet121':
        model = models.densenet121(pretrained=True)
    else:
        print ("Modell {} nicht bekannt, es wird automatisch alexnet verwendet".format (structure))
        model = models.alexnet(pretrained = True)
        structure="alexnet"
        
        
    # Training für das Modell aussetzen    
    for param in model.parameters():
        param.requires_grad = False

    # Definition des Classifiers
    model.classifier = nn.Sequential(OrderedDict([
            ('dropout',nn.Dropout(dropout)),
            ('inputs', nn.Linear(structures[structure], hidden_units)),
            ('relu1', nn.ReLU()),
            ('hidden_layer1', nn.Linear(hidden_units, 1000)),
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(1000,len(trainloader))),
            ('output', nn.LogSoftmax(dim=1)) ]))
        
        
    # model.classifier = classifier
    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.classifier.parameters(), learning_rate)
    #model.cuda()
        
    return model , optimizer ,criterion 

    

model,optimizer,criterion = nn_setup()

# %%
def training (epochs = 3, print_every = 20, device ="cuda"):
    #starting points:
    steps = 0
    loss_show=[]
    
    print ("Modell wir nach {} transferiert".format(device))
    # change to cuda
    model.to(device)
    print ("Starting Training mit Epochen:", epochs)
    for e in range(epochs):
        running_loss = 0
        for i, data in enumerate (trainloader,0):
            inputs, labels = data
            
            if device == "cuda":
                inputs = Variable(inputs.cuda())
                labels = Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
                    
            timeset = time.time()
            steps += 1
            
            inputs = inputs.to(device)
            labels =  labels.to(device)
            
            optimizer.zero_grad()
            
            # Forward and backward passes
            output = model.forward(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            if steps % print_every == 0:
                model.eval()
                vlost = 0
                accuracy=0
                
                
                for i, data2 in enumerate(vloader,0):
                    inputs2, labels2 = data2
                    if device == "cuda":
                        inputs2 = Variable(inputs2.cuda())
                        labels2 = Variable(labels2.cuda())
                    else:
                        inputs2, labels2 = Variable(inputs2), Variable(labels2)
                    
                    steps += 1
            
                    inputs2 = inputs2.to(device)
                    labels2 = labels2.to(device)
                    
                    optimizer.zero_grad()
                    inputs2, labels2 = inputs2.to(device) , labels2.to(device)
                    model.to(device)
                    with torch.no_grad(): 
                        outputs = model.forward(inputs2)
                        vlost = criterion(outputs,labels2).item() 
                        ps = torch.exp(outputs).data 
                        equality = (labels2.data == ps.max(1)[1])
                        accuracy += equality.type_as(torch.FloatTensor()).mean()
                        
                vlost = vlost / len(vloader)
                accuracy = accuracy /len(vloader)
                
                        
                
                print("Epoch: {}/{}... ".format(e+1, epochs),
                      "Loss: {:.4f}".format(running_loss/print_every),
                      "Validation Lost {:.4f}".format(vlost),
                       "Accuracy: {:.4f}".format(accuracy))
                
                
                running_loss = 0
    
    
training(6,15,"cuda")
# Out:
# Modell wir nach cuda transferiert
# Starting Training mit Epochen: 6
# Epoch: 1/6...  Loss: 4.5660 Validation Lost 0.3339 Accuracy: 0.0656
# Epoch: 1/6...  Loss: 0.5865 Validation Lost 0.3369 Accuracy: 0.0809
# Epoch: 1/6...  Loss: 0.5836 Validation Lost 0.3359 Accuracy: 0.0999
# Epoch: 1/6...  Loss: 0.5660 Validation Lost 0.3226 Accuracy: 0.1135
# Epoch: 1/6...  Loss: 0.5690 Validation Lost 0.3096 Accuracy: 0.1176
# Epoch: 1/6...  Loss: 0.5524 Validation Lost 0.3212 Accuracy: 0.1282
# Epoch: 1/6...  Loss: 0.5454 Validation Lost 0.2818 Accuracy: 0.1425
# Epoch: 1/6...  Loss: 0.5414 Validation Lost 0.3309 Accuracy: 0.1615
# Epoch: 1/6...  Loss: 0.5065 Validation Lost 0.2836 Accuracy: 0.1658
# Epoch: 1/6...  Loss: 0.5207 Validation Lost 0.2604 Accuracy: 0.1660
# Epoch: 1/6...  Loss: 0.4852 Validation Lost 0.2736 Accuracy: 0.1983
# Epoch: 1/6...  Loss: 0.4867 Validation Lost 0.2500 Accuracy: 0.2070
# Epoch: 1/6...  Loss: 0.4832 Validation Lost 0.2665 Accuracy: 0.2319
# Epoch: 1/6...  Loss: 0.4506 Validation Lost 0.2476 Accuracy: 0.2357
# Epoch: 1/6...  Loss: 0.4278 Validation Lost 0.2316 Accuracy: 0.2518
# Epoch: 1/6...  Loss: 0.4257 Validation Lost 0.2382 Accuracy: 0.2391
# Epoch: 1/6...  Loss: 0.4356 Validation Lost 0.2152 Accuracy: 0.3101
# Epoch: 1/6...  Loss: 0.4079 Validation Lost 0.2105 Accuracy: 0.3411
# Epoch: 1/6...  Loss: 0.3984 Validation Lost 0.1910 Accuracy: 0.3325
# Epoch: 1/6...  Loss: 0.3751 Validation Lost 0.1849 Accuracy: 0.3363
# Epoch: 1/6...  Loss: 0.3986 Validation Lost 0.2266 Accuracy: 0.3189
# Epoch: 1/6...  Loss: 0.3714 Validation Lost 0.1732 Accuracy: 0.3776
# Epoch: 1/6...  Loss: 0.3669 Validation Lost 0.1674 Accuracy: 0.4016
# Epoch: 1/6...  Loss: 0.3291 Validation Lost 0.1837 Accuracy: 0.3986
# Epoch: 1/6...  Loss: 0.3218 Validation Lost 0.1726 Accuracy: 0.3951
# Epoch: 1/6...  Loss: 0.3400 Validation Lost 0.1248 Accuracy: 0.4352
# Epoch: 1/6...  Loss: 0.3623 Validation Lost 0.2244 Accuracy: 0.4056
# Epoch: 1/6...  Loss: 0.3455 Validation Lost 0.1435 Accuracy: 0.4358
# Epoch: 1/6...  Loss: 0.3393 Validation Lost 0.2282 Accuracy: 0.4281
# Epoch: 1/6...  Loss: 0.2908 Validation Lost 0.1630 Accuracy: 0.4451
# Epoch: 1/6...  Loss: 0.3383 Validation Lost 0.1411 Accuracy: 0.4705
# Epoch: 1/6...  Loss: 0.3172 Validation Lost 0.1536 Accuracy: 0.4563
# Epoch: 1/6...  Loss: 0.3005 Validation Lost 0.1696 Accuracy: 0.4686
# Epoch: 1/6...  Loss: 0.3309 Validation Lost 0.1456 Accuracy: 0.4804
# Epoch: 1/6...  Loss: 0.2660 Validation Lost 0.1853 Accuracy: 0.4930
# Epoch: 1/6...  Loss: 0.2968 Validation Lost 0.1625 Accuracy: 0.4590
# Epoch: 1/6...  Loss: 0.2940 Validation Lost 0.1442 Accuracy: 0.4949
# Epoch: 1/6...  Loss: 0.2668 Validation Lost 0.1047 Accuracy: 0.5228
# Epoch: 1/6...  Loss: 0.3027 Validation Lost 0.1051 Accuracy: 0.5192
# Epoch: 1/6...  Loss: 0.2630 Validation Lost 0.1205 Accuracy: 0.5350
# Epoch: 1/6...  Loss: 0.3046 Validation Lost 0.1202 Accuracy: 0.5522
# Epoch: 1/6...  Loss: 0.2847 Validation Lost 0.1097 Accuracy: 0.5702
# Epoch: 1/6...  Loss: 0.2491 Validation Lost 0.1494 Accuracy: 0.5704
# Epoch: 1/6...  Loss: 0.2608 Validation Lost 0.1251 Accuracy: 0.5650
# Epoch: 1/6...  Loss: 0.2506 Validation Lost 0.1062 Accuracy: 0.5564
# Epoch: 2/6...  Loss: 0.2791 Validation Lost 0.1335 Accuracy: 0.5407
# Epoch: 2/6...  Loss: 0.2582 Validation Lost 0.1093 Accuracy: 0.5906
# Epoch: 2/6...  Loss: 0.2530 Validation Lost 0.1054 Accuracy: 0.5680
# Epoch: 2/6...  Loss: 0.2537 Validation Lost 0.1381 Accuracy: 0.5604
# Epoch: 2/6...  Loss: 0.2210 Validation Lost 0.1395 Accuracy: 0.5498
# Epoch: 2/6...  Loss: 0.2540 Validation Lost 0.1375 Accuracy: 0.5793
# Epoch: 2/6...  Loss: 0.2354 Validation Lost 0.1113 Accuracy: 0.5918
# Epoch: 2/6...  Loss: 0.2415 Validation Lost 0.0880 Accuracy: 0.6052
# Epoch: 2/6...  Loss: 0.2462 Validation Lost 0.1257 Accuracy: 0.6116
# Epoch: 2/6...  Loss: 0.2301 Validation Lost 0.0892 Accuracy: 0.5751
# Epoch: 2/6...  Loss: 0.1930 Validation Lost 0.0967 Accuracy: 0.6085
# Epoch: 2/6...  Loss: 0.2715 Validation Lost 0.1061 Accuracy: 0.6165
# Epoch: 2/6...  Loss: 0.2474 Validation Lost 0.0934 Accuracy: 0.6455
# Epoch: 2/6...  Loss: 0.2461 Validation Lost 0.1067 Accuracy: 0.6030
# Epoch: 2/6...  Loss: 0.2090 Validation Lost 0.1373 Accuracy: 0.5831
# Epoch: 2/6...  Loss: 0.2468 Validation Lost 0.1026 Accuracy: 0.5951
# Epoch: 2/6...  Loss: 0.1929 Validation Lost 0.1007 Accuracy: 0.5980
# Epoch: 2/6...  Loss: 0.2396 Validation Lost 0.1117 Accuracy: 0.6336
# Epoch: 2/6...  Loss: 0.2008 Validation Lost 0.1145 Accuracy: 0.6399
# Epoch: 2/6...  Loss: 0.1804 Validation Lost 0.1350 Accuracy: 0.6274
# Epoch: 2/6...  Loss: 0.2341 Validation Lost 0.0699 Accuracy: 0.6512
# Epoch: 2/6...  Loss: 0.2210 Validation Lost 0.1379 Accuracy: 0.6406
# Epoch: 2/6...  Loss: 0.2408 Validation Lost 0.0812 Accuracy: 0.6500
# Epoch: 2/6...  Loss: 0.2261 Validation Lost 0.0920 Accuracy: 0.6481
# Epoch: 2/6...  Loss: 0.1850 Validation Lost 0.0832 Accuracy: 0.6490
# Epoch: 2/6...  Loss: 0.2068 Validation Lost 0.0901 Accuracy: 0.6670
# Epoch: 2/6...  Loss: 0.2108 Validation Lost 0.0611 Accuracy: 0.6625
# Epoch: 2/6...  Loss: 0.1994 Validation Lost 0.0911 Accuracy: 0.6587
# Epoch: 2/6...  Loss: 0.2137 Validation Lost 0.1114 Accuracy: 0.6622
# Epoch: 2/6...  Loss: 0.2134 Validation Lost 0.1234 Accuracy: 0.6796
# Epoch: 2/6...  Loss: 0.2216 Validation Lost 0.0704 Accuracy: 0.6759
# Epoch: 2/6...  Loss: 0.2220 Validation Lost 0.0863 Accuracy: 0.7001
# Epoch: 2/6...  Loss: 0.1983 Validation Lost 0.1007 Accuracy: 0.6707
# Epoch: 2/6...  Loss: 0.1984 Validation Lost 0.0950 Accuracy: 0.6703
# Epoch: 2/6...  Loss: 0.1726 Validation Lost 0.0828 Accuracy: 0.6759
# Epoch: 2/6...  Loss: 0.1918 Validation Lost 0.0835 Accuracy: 0.6802
# Epoch: 2/6...  Loss: 0.1928 Validation Lost 0.1179 Accuracy: 0.6739
# Epoch: 2/6...  Loss: 0.1856 Validation Lost 0.0756 Accuracy: 0.6812
# Epoch: 2/6...  Loss: 0.1909 Validation Lost 0.0907 Accuracy: 0.6732
# Epoch: 2/6...  Loss: 0.2104 Validation Lost 0.0969 Accuracy: 0.6700
# Epoch: 2/6...  Loss: 0.2265 Validation Lost 0.0650 Accuracy: 0.6652
# Epoch: 2/6...  Loss: 0.2200 Validation Lost 0.0961 Accuracy: 0.6076
# Epoch: 2/6...  Loss: 0.1885 Validation Lost 0.1168 Accuracy: 0.6378
# Epoch: 2/6...  Loss: 0.2057 Validation Lost 0.1040 Accuracy: 0.6691
# Epoch: 2/6...  Loss: 0.1780 Validation Lost 0.1123 Accuracy: 0.6880
# Epoch: 2/6...  Loss: 0.1726 Validation Lost 0.0757 Accuracy: 0.7034
# Epoch: 2/6...  Loss: 0.1623 Validation Lost 0.0628 Accuracy: 0.6883
# Epoch: 2/6...  Loss: 0.1630 Validation Lost 0.0566 Accuracy: 0.6897
# Epoch: 2/6...  Loss: 0.1771 Validation Lost 0.0780 Accuracy: 0.6902
# Epoch: 2/6...  Loss: 0.1827 Validation Lost 0.0860 Accuracy: 0.7132
# Epoch: 2/6...  Loss: 0.1840 Validation Lost 0.1001 Accuracy: 0.7156
# Epoch: 3/6...  Loss: 0.0578 Validation Lost 0.0773 Accuracy: 0.7156
# Epoch: 3/6...  Loss: 0.1486 Validation Lost 0.0930 Accuracy: 0.7237
# Epoch: 3/6...  Loss: 0.1776 Validation Lost 0.0994 Accuracy: 0.7112
# Epoch: 3/6...  Loss: 0.1673 Validation Lost 0.0690 Accuracy: 0.7166
# Epoch: 3/6...  Loss: 0.1832 Validation Lost 0.0669 Accuracy: 0.7200
# Epoch: 3/6...  Loss: 0.1485 Validation Lost 0.1146 Accuracy: 0.7050
# Epoch: 3/6...  Loss: 0.1568 Validation Lost 0.0964 Accuracy: 0.7142
# Epoch: 3/6...  Loss: 0.1466 Validation Lost 0.0705 Accuracy: 0.7144
# Epoch: 3/6...  Loss: 0.1433 Validation Lost 0.0798 Accuracy: 0.7182
# Epoch: 3/6...  Loss: 0.1603 Validation Lost 0.0617 Accuracy: 0.7310
# Epoch: 3/6...  Loss: 0.1755 Validation Lost 0.0539 Accuracy: 0.7221
# Epoch: 3/6...  Loss: 0.1708 Validation Lost 0.0803 Accuracy: 0.7104
# Epoch: 3/6...  Loss: 0.2047 Validation Lost 0.1135 Accuracy: 0.7046
# Epoch: 3/6...  Loss: 0.1510 Validation Lost 0.0738 Accuracy: 0.7156
# Epoch: 3/6...  Loss: 0.1318 Validation Lost 0.0593 Accuracy: 0.7056
# Epoch: 3/6...  Loss: 0.1947 Validation Lost 0.1106 Accuracy: 0.7326
# Epoch: 3/6...  Loss: 0.1805 Validation Lost 0.0673 Accuracy: 0.7472
# Epoch: 3/6...  Loss: 0.1289 Validation Lost 0.1008 Accuracy: 0.7311
# Epoch: 3/6...  Loss: 0.1527 Validation Lost 0.0756 Accuracy: 0.7324
# Epoch: 3/6...  Loss: 0.1475 Validation Lost 0.0618 Accuracy: 0.6998
# Epoch: 3/6...  Loss: 0.1545 Validation Lost 0.0912 Accuracy: 0.6821
# Epoch: 3/6...  Loss: 0.1846 Validation Lost 0.0522 Accuracy: 0.7262
# Epoch: 3/6...  Loss: 0.1887 Validation Lost 0.0668 Accuracy: 0.7520
# Epoch: 3/6...  Loss: 0.1606 Validation Lost 0.1035 Accuracy: 0.7367
# Epoch: 3/6...  Loss: 0.2168 Validation Lost 0.0451 Accuracy: 0.7624
# Epoch: 3/6...  Loss: 0.1631 Validation Lost 0.0692 Accuracy: 0.7468
# Epoch: 3/6...  Loss: 0.1802 Validation Lost 0.0660 Accuracy: 0.7619
# Epoch: 3/6...  Loss: 0.1938 Validation Lost 0.0899 Accuracy: 0.7633
# Epoch: 3/6...  Loss: 0.1581 Validation Lost 0.0645 Accuracy: 0.7673
# Epoch: 3/6...  Loss: 0.1695 Validation Lost 0.0571 Accuracy: 0.7691
# Epoch: 3/6...  Loss: 0.1614 Validation Lost 0.0843 Accuracy: 0.7501
# Epoch: 3/6...  Loss: 0.1700 Validation Lost 0.0632 Accuracy: 0.7432
# Epoch: 3/6...  Loss: 0.1603 Validation Lost 0.0792 Accuracy: 0.7314
# Epoch: 3/6...  Loss: 0.1522 Validation Lost 0.0485 Accuracy: 0.7520
# Epoch: 3/6...  Loss: 0.1769 Validation Lost 0.0710 Accuracy: 0.7403
# Epoch: 3/6...  Loss: 0.1970 Validation Lost 0.0794 Accuracy: 0.7575
# Epoch: 3/6...  Loss: 0.1517 Validation Lost 0.0624 Accuracy: 0.7582
# Epoch: 3/6...  Loss: 0.1517 Validation Lost 0.0798 Accuracy: 0.7676
# Epoch: 3/6...  Loss: 0.1822 Validation Lost 0.0801 Accuracy: 0.7733
# Epoch: 3/6...  Loss: 0.1758 Validation Lost 0.0565 Accuracy: 0.7739
# Epoch: 3/6...  Loss: 0.1502 Validation Lost 0.0499 Accuracy: 0.7581
# Epoch: 3/6...  Loss: 0.1709 Validation Lost 0.0701 Accuracy: 0.7604
# Epoch: 3/6...  Loss: 0.1984 Validation Lost 0.0736 Accuracy: 0.7602
# Epoch: 3/6...  Loss: 0.1336 Validation Lost 0.0565 Accuracy: 0.7800
# Epoch: 3/6...  Loss: 0.1241 Validation Lost 0.0619 Accuracy: 0.7904
# Epoch: 3/6...  Loss: 0.1274 Validation Lost 0.0685 Accuracy: 0.7697
# Epoch: 3/6...  Loss: 0.1505 Validation Lost 0.0869 Accuracy: 0.7522
# Epoch: 3/6...  Loss: 0.1597 Validation Lost 0.0755 Accuracy: 0.7420
# Epoch: 3/6...  Loss: 0.1575 Validation Lost 0.0838 Accuracy: 0.7233
# Epoch: 3/6...  Loss: 0.1341 Validation Lost 0.0812 Accuracy: 0.7127
# Epoch: 3/6...  Loss: 0.1560 Validation Lost 0.0878 Accuracy: 0.7422
# Epoch: 3/6...  Loss: 0.1489 Validation Lost 0.0721 Accuracy: 0.7460
# Epoch: 4/6...  Loss: 0.1359 Validation Lost 0.0773 Accuracy: 0.7243
# Epoch: 4/6...  Loss: 0.1693 Validation Lost 0.1083 Accuracy: 0.7122
# Epoch: 4/6...  Loss: 0.1382 Validation Lost 0.0851 Accuracy: 0.6953
# Epoch: 4/6...  Loss: 0.1760 Validation Lost 0.0590 Accuracy: 0.7288
# Epoch: 4/6...  Loss: 0.1666 Validation Lost 0.0484 Accuracy: 0.7341
# Epoch: 4/6...  Loss: 0.1584 Validation Lost 0.0560 Accuracy: 0.7535
# Epoch: 4/6...  Loss: 0.2015 Validation Lost 0.0534 Accuracy: 0.7617
# Epoch: 4/6...  Loss: 0.1495 Validation Lost 0.0516 Accuracy: 0.7590
# Epoch: 4/6...  Loss: 0.1695 Validation Lost 0.0710 Accuracy: 0.7099
# Epoch: 4/6...  Loss: 0.1595 Validation Lost 0.0489 Accuracy: 0.7150
# Epoch: 4/6...  Loss: 0.1605 Validation Lost 0.0802 Accuracy: 0.7249
# Epoch: 4/6...  Loss: 0.1678 Validation Lost 0.0748 Accuracy: 0.7434
# Epoch: 4/6...  Loss: 0.1464 Validation Lost 0.0605 Accuracy: 0.7544
# Epoch: 4/6...  Loss: 0.1455 Validation Lost 0.0529 Accuracy: 0.7454
# Epoch: 4/6...  Loss: 0.1400 Validation Lost 0.0623 Accuracy: 0.7333
# Epoch: 4/6...  Loss: 0.1782 Validation Lost 0.0668 Accuracy: 0.7388
# Epoch: 4/6...  Loss: 0.1649 Validation Lost 0.0772 Accuracy: 0.7307
# Epoch: 4/6...  Loss: 0.1430 Validation Lost 0.0887 Accuracy: 0.7295
# Epoch: 4/6...  Loss: 0.1726 Validation Lost 0.0456 Accuracy: 0.7427
# Epoch: 4/6...  Loss: 0.1741 Validation Lost 0.1169 Accuracy: 0.7285
# Epoch: 4/6...  Loss: 0.1503 Validation Lost 0.0795 Accuracy: 0.7365
# Epoch: 4/6...  Loss: 0.1431 Validation Lost 0.0637 Accuracy: 0.7245
# Epoch: 4/6...  Loss: 0.1650 Validation Lost 0.0761 Accuracy: 0.7386
# Epoch: 4/6...  Loss: 0.1302 Validation Lost 0.0604 Accuracy: 0.7724
# Epoch: 4/6...  Loss: 0.1123 Validation Lost 0.0671 Accuracy: 0.7800
# Epoch: 4/6...  Loss: 0.1161 Validation Lost 0.0395 Accuracy: 0.7849
# Epoch: 4/6...  Loss: 0.1386 Validation Lost 0.0708 Accuracy: 0.7710
# Epoch: 4/6...  Loss: 0.1468 Validation Lost 0.0560 Accuracy: 0.7597
# Epoch: 4/6...  Loss: 0.1539 Validation Lost 0.1324 Accuracy: 0.7638
# Epoch: 4/6...  Loss: 0.1462 Validation Lost 0.0548 Accuracy: 0.7637
# Epoch: 4/6...  Loss: 0.1212 Validation Lost 0.0499 Accuracy: 0.7604
# Epoch: 4/6...  Loss: 0.1490 Validation Lost 0.0433 Accuracy: 0.7725
# Epoch: 4/6...  Loss: 0.1426 Validation Lost 0.0609 Accuracy: 0.7605
# Epoch: 4/6...  Loss: 0.1224 Validation Lost 0.0700 Accuracy: 0.7655
# Epoch: 4/6...  Loss: 0.1571 Validation Lost 0.0496 Accuracy: 0.7667
# Epoch: 4/6...  Loss: 0.1020 Validation Lost 0.1032 Accuracy: 0.7772
# Epoch: 4/6...  Loss: 0.1202 Validation Lost 0.0509 Accuracy: 0.7803
# Epoch: 4/6...  Loss: 0.1477 Validation Lost 0.1097 Accuracy: 0.7901
# Epoch: 4/6...  Loss: 0.1445 Validation Lost 0.0846 Accuracy: 0.7704
# Epoch: 4/6...  Loss: 0.1250 Validation Lost 0.0367 Accuracy: 0.7818
# Epoch: 4/6...  Loss: 0.1511 Validation Lost 0.1141 Accuracy: 0.7600
# Epoch: 4/6...  Loss: 0.1685 Validation Lost 0.0815 Accuracy: 0.7386
# Epoch: 4/6...  Loss: 0.1502 Validation Lost 0.0588 Accuracy: 0.7510
# Epoch: 4/6...  Loss: 0.1600 Validation Lost 0.0544 Accuracy: 0.7701
# Epoch: 4/6...  Loss: 0.1285 Validation Lost 0.0574 Accuracy: 0.7760
# Epoch: 4/6...  Loss: 0.1830 Validation Lost 0.0456 Accuracy: 0.7762
# Epoch: 4/6...  Loss: 0.1581 Validation Lost 0.0665 Accuracy: 0.7691
# Epoch: 4/6...  Loss: 0.1462 Validation Lost 0.0448 Accuracy: 0.7731
# Epoch: 4/6...  Loss: 0.1606 Validation Lost 0.0508 Accuracy: 0.7851
# Epoch: 4/6...  Loss: 0.1289 Validation Lost 0.0412 Accuracy: 0.7837
# Epoch: 4/6...  Loss: 0.1442 Validation Lost 0.0521 Accuracy: 0.7727
# Epoch: 5/6...  Loss: 0.0554 Validation Lost 0.0787 Accuracy: 0.7687
# Epoch: 5/6...  Loss: 0.1049 Validation Lost 0.0371 Accuracy: 0.7861
# Epoch: 5/6...  Loss: 0.1158 Validation Lost 0.0611 Accuracy: 0.7856
# Epoch: 5/6...  Loss: 0.1119 Validation Lost 0.0744 Accuracy: 0.7731
# Epoch: 5/6...  Loss: 0.1260 Validation Lost 0.0416 Accuracy: 0.7983
# Epoch: 5/6...  Loss: 0.1418 Validation Lost 0.0245 Accuracy: 0.7832
# Epoch: 5/6...  Loss: 0.1395 Validation Lost 0.0517 Accuracy: 0.7688
# Epoch: 5/6...  Loss: 0.1552 Validation Lost 0.0654 Accuracy: 0.7659
# Epoch: 5/6...  Loss: 0.1446 Validation Lost 0.0667 Accuracy: 0.7872
# Epoch: 5/6...  Loss: 0.1214 Validation Lost 0.0631 Accuracy: 0.7760
# Epoch: 5/6...  Loss: 0.1307 Validation Lost 0.0857 Accuracy: 0.7723
# Epoch: 5/6...  Loss: 0.1405 Validation Lost 0.0537 Accuracy: 0.7781
# Epoch: 5/6...  Loss: 0.1523 Validation Lost 0.0354 Accuracy: 0.7938
# Epoch: 5/6...  Loss: 0.0948 Validation Lost 0.0336 Accuracy: 0.7957
# Epoch: 5/6...  Loss: 0.1043 Validation Lost 0.0781 Accuracy: 0.7733
# Epoch: 5/6...  Loss: 0.1314 Validation Lost 0.0321 Accuracy: 0.7762
# Epoch: 5/6...  Loss: 0.1220 Validation Lost 0.0474 Accuracy: 0.7760
# Epoch: 5/6...  Loss: 0.1160 Validation Lost 0.0830 Accuracy: 0.7807
# Epoch: 5/6...  Loss: 0.1492 Validation Lost 0.0686 Accuracy: 0.7625
# Epoch: 5/6...  Loss: 0.1106 Validation Lost 0.0707 Accuracy: 0.7784
# Epoch: 5/6...  Loss: 0.1578 Validation Lost 0.0462 Accuracy: 0.7846
# Epoch: 5/6...  Loss: 0.1621 Validation Lost 0.0450 Accuracy: 0.7962
# Epoch: 5/6...  Loss: 0.1091 Validation Lost 0.0495 Accuracy: 0.8097
# Epoch: 5/6...  Loss: 0.1189 Validation Lost 0.0316 Accuracy: 0.8105
# Epoch: 5/6...  Loss: 0.1257 Validation Lost 0.0585 Accuracy: 0.7916
# Epoch: 5/6...  Loss: 0.1224 Validation Lost 0.0479 Accuracy: 0.7851
# Epoch: 5/6...  Loss: 0.1268 Validation Lost 0.0484 Accuracy: 0.7880
# Epoch: 5/6...  Loss: 0.1399 Validation Lost 0.0830 Accuracy: 0.7831
# Epoch: 5/6...  Loss: 0.0901 Validation Lost 0.0355 Accuracy: 0.7768
# Epoch: 5/6...  Loss: 0.1445 Validation Lost 0.0905 Accuracy: 0.7848
# Epoch: 5/6...  Loss: 0.0982 Validation Lost 0.0448 Accuracy: 0.7729
# Epoch: 5/6...  Loss: 0.1400 Validation Lost 0.0663 Accuracy: 0.7853
# Epoch: 5/6...  Loss: 0.1262 Validation Lost 0.0542 Accuracy: 0.7834
# Epoch: 5/6...  Loss: 0.1545 Validation Lost 0.0343 Accuracy: 0.8035
# Epoch: 5/6...  Loss: 0.1607 Validation Lost 0.0490 Accuracy: 0.8095
# Epoch: 5/6...  Loss: 0.1562 Validation Lost 0.0699 Accuracy: 0.8169
# Epoch: 5/6...  Loss: 0.1068 Validation Lost 0.0380 Accuracy: 0.8242
# Epoch: 5/6...  Loss: 0.1273 Validation Lost 0.0704 Accuracy: 0.8213
# Epoch: 5/6...  Loss: 0.1296 Validation Lost 0.0661 Accuracy: 0.8078
# Epoch: 5/6...  Loss: 0.1178 Validation Lost 0.0516 Accuracy: 0.7935
# Epoch: 5/6...  Loss: 0.1199 Validation Lost 0.0172 Accuracy: 0.7928
# Epoch: 5/6...  Loss: 0.1196 Validation Lost 0.0916 Accuracy: 0.7904
# Epoch: 5/6...  Loss: 0.1100 Validation Lost 0.0373 Accuracy: 0.8050
# Epoch: 5/6...  Loss: 0.1383 Validation Lost 0.0646 Accuracy: 0.8109
# Epoch: 5/6...  Loss: 0.1178 Validation Lost 0.0386 Accuracy: 0.8158
# Epoch: 5/6...  Loss: 0.1324 Validation Lost 0.0649 Accuracy: 0.8109
# Epoch: 5/6...  Loss: 0.1237 Validation Lost 0.0666 Accuracy: 0.7997
# Epoch: 5/6...  Loss: 0.1244 Validation Lost 0.0593 Accuracy: 0.8052
# Epoch: 5/6...  Loss: 0.1200 Validation Lost 0.0371 Accuracy: 0.8101
# Epoch: 5/6...  Loss: 0.1301 Validation Lost 0.0594 Accuracy: 0.8167
# Epoch: 5/6...  Loss: 0.1211 Validation Lost 0.0475 Accuracy: 0.8047
# Epoch: 5/6...  Loss: 0.1107 Validation Lost 0.0405 Accuracy: 0.7839
# Epoch: 6/6...  Loss: 0.1596 Validation Lost 0.0417 Accuracy: 0.7837
# Epoch: 6/6...  Loss: 0.1220 Validation Lost 0.0624 Accuracy: 0.7901
# Epoch: 6/6...  Loss: 0.1335 Validation Lost 0.0424 Accuracy: 0.8007
# Epoch: 6/6...  Loss: 0.1280 Validation Lost 0.0454 Accuracy: 0.7983
# Epoch: 6/6...  Loss: 0.1421 Validation Lost 0.0749 Accuracy: 0.7908
# Epoch: 6/6...  Loss: 0.1273 Validation Lost 0.0349 Accuracy: 0.7873
# Epoch: 6/6...  Loss: 0.1639 Validation Lost 0.0914 Accuracy: 0.7910
# Epoch: 6/6...  Loss: 0.1028 Validation Lost 0.0660 Accuracy: 0.7923
# Epoch: 6/6...  Loss: 0.1319 Validation Lost 0.0437 Accuracy: 0.7884
# Epoch: 6/6...  Loss: 0.1253 Validation Lost 0.0507 Accuracy: 0.8112
# Epoch: 6/6...  Loss: 0.0932 Validation Lost 0.0647 Accuracy: 0.8148
# Epoch: 6/6...  Loss: 0.1183 Validation Lost 0.0392 Accuracy: 0.8290
# Epoch: 6/6...  Loss: 0.1288 Validation Lost 0.0472 Accuracy: 0.8364
# Epoch: 6/6...  Loss: 0.1010 Validation Lost 0.0298 Accuracy: 0.8337
# Epoch: 6/6...  Loss: 0.1177 Validation Lost 0.0269 Accuracy: 0.8270
# Epoch: 6/6...  Loss: 0.1336 Validation Lost 0.0405 Accuracy: 0.8228
# Epoch: 6/6...  Loss: 0.1179 Validation Lost 0.1138 Accuracy: 0.8198
# Epoch: 6/6...  Loss: 0.1137 Validation Lost 0.0424 Accuracy: 0.8188
# Epoch: 6/6...  Loss: 0.1418 Validation Lost 0.0550 Accuracy: 0.8340
# Epoch: 6/6...  Loss: 0.1145 Validation Lost 0.0318 Accuracy: 0.8309
# Epoch: 6/6...  Loss: 0.1185 Validation Lost 0.0955 Accuracy: 0.7983
# Epoch: 6/6...  Loss: 0.1256 Validation Lost 0.1090 Accuracy: 0.7941
# Epoch: 6/6...  Loss: 0.1107 Validation Lost 0.0417 Accuracy: 0.8067
# Epoch: 6/6...  Loss: 0.1101 Validation Lost 0.0488 Accuracy: 0.7985
# Epoch: 6/6...  Loss: 0.0949 Validation Lost 0.0718 Accuracy: 0.7896
# Epoch: 6/6...  Loss: 0.1228 Validation Lost 0.0422 Accuracy: 0.7873
# Epoch: 6/6...  Loss: 0.1294 Validation Lost 0.0573 Accuracy: 0.8016
# Epoch: 6/6...  Loss: 0.1127 Validation Lost 0.0460 Accuracy: 0.8143
# Epoch: 6/6...  Loss: 0.1083 Validation Lost 0.0308 Accuracy: 0.8158
# Epoch: 6/6...  Loss: 0.0991 Validation Lost 0.0575 Accuracy: 0.8182
# Epoch: 6/6...  Loss: 0.1027 Validation Lost 0.0514 Accuracy: 0.8100
# Epoch: 6/6...  Loss: 0.1507 Validation Lost 0.0575 Accuracy: 0.8201
# Epoch: 6/6...  Loss: 0.1076 Validation Lost 0.0503 Accuracy: 0.8179
# Epoch: 6/6...  Loss: 0.1340 Validation Lost 0.0649 Accuracy: 0.8061
# Epoch: 6/6...  Loss: 0.1189 Validation Lost 0.0719 Accuracy: 0.8028
# Epoch: 6/6...  Loss: 0.1334 Validation Lost 0.0405 Accuracy: 0.8134
# Epoch: 6/6...  Loss: 0.1171 Validation Lost 0.0601 Accuracy: 0.8109
# Epoch: 6/6...  Loss: 0.1272 Validation Lost 0.0632 Accuracy: 0.8025
# Epoch: 6/6...  Loss: 0.1311 Validation Lost 0.0463 Accuracy: 0.8160
# Epoch: 6/6...  Loss: 0.0962 Validation Lost 0.0352 Accuracy: 0.8294
# Epoch: 6/6...  Loss: 0.1109 Validation Lost 0.0385 Accuracy: 0.8242
# Epoch: 6/6...  Loss: 0.0920 Validation Lost 0.0876 Accuracy: 0.8075
# Epoch: 6/6...  Loss: 0.1378 Validation Lost 0.0439 Accuracy: 0.8242
# Epoch: 6/6...  Loss: 0.1124 Validation Lost 0.0609 Accuracy: 0.8304
# Epoch: 6/6...  Loss: 0.1398 Validation Lost 0.0546 Accuracy: 0.8364
# Epoch: 6/6...  Loss: 0.1148 Validation Lost 0.0458 Accuracy: 0.8364
# Epoch: 6/6...  Loss: 0.1498 Validation Lost 0.0763 Accuracy: 0.8225
# Epoch: 6/6...  Loss: 0.1288 Validation Lost 0.1251 Accuracy: 0.8080
# Epoch: 6/6...  Loss: 0.1286 Validation Lost 0.0457 Accuracy: 0.8088
# Epoch: 6/6...  Loss: 0.0973 Validation Lost 0.0819 Accuracy: 0.8120
# Epoch: 6/6...  Loss: 0.1344 Validation Lost 0.0856 Accuracy: 0.8170

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
def testing (testloader,device_test="cuda"):
    correct = 0
    total = 0
    model.to(device_test)
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device_test), labels.to(device_test)
            outputs = model(images)
            loose, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print("'Accuracy of the trained model: ", (100 * correct / total), "%")
    
testing (testloader, "cuda")
# Out:
# 'Accuracy of the trained model:  80.34188034188034 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
def save_model():
    model.class_to_idx = train_data.class_to_idx
    model.cpu
    torch.save({'structure' :'vgg16',
            'hidden_layer1':120,
            'state_dict':model.state_dict(),
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')
save_model()

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(path):
    checkpoint = torch.load('checkpoint.pth')
    structure = checkpoint['structure']
    hidden_layer1 = checkpoint['hidden_layer1']
    model,_,_ = nn_setup(structure, 0.5,hidden_layer1)
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    
# model = load_model('checkpoint.pth')  
#print(model)

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    pil_image = Image.open(image)
    im_resized = pil_image.resize((224,224))
    np_image = np.array(im_resized)
    np_image = np_image/255
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean)/std
    np_image = np_image.transpose(2, 0, 1)
    return np_image
#processed_image = process_image("/home/workspace/aipnd-project/flowers/test/10/image_07090.jpg")

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    #image = image.numpy().transpose((1, 2, 0))
    image = image.transpose(1,2,0)
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax
                    
imshow(process_image("/home/workspace/aipnd-project/flowers/test/10/image_07090.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
model.class_to_idx =train_data.class_to_idx

ctx = model.class_to_idx


def predict(image_path, model, top_k=5):   
    model.to("cuda")
    img_pip = process_image(image_path)
    img_tensor = torch.from_numpy(img_pip)
    img_tensor = img_tensor.unsqueeze_(0)
    img_tensor = img_tensor.float()
    with torch.no_grad():
        output = model.forward(img_tensor.to("cuda"))
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(top_k)
    
img = ("/home/workspace/aipnd-project/flowers/test/10/image_07090.jpg")
probability, classification = predict(img, model)
print(probability)
print(classification)

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def check_sanity():
    # process image and get predisction of classes
    img_path = ("/home/workspace/aipnd-project/flowers/test/10/image_07090.jpg")
    
    img_filename = img_path.split('/')[-2]
    flower_name = cat_to_name[img_filename]
    
    probs, classes = predict(img_path, model)
    
    
    #torch tensors to cpu
    probs = probs.to(torch.device("cpu"))
    classes = classes.to(torch.device("cpu"))
                
    #squeeze to 1 Dim
    probs = probs.data.numpy().squeeze()
    classes = classes.data.numpy().squeeze()   
  
            
    #Build Chart
    axs = imshow(process_image(img_path))
    axs.set_title(flower_name)
    plt.rcdefaults()
    
    fig, ax = plt.subplots()
    y_pos = np.arange(len(classes))
    ax.barh(y_pos, probs,align='center')
    ax.set_yticks(y_pos)
    ax.set_yticklabels([cat_to_name[str(x)] for x in classes] )
    ax.invert_yaxis()
    ax.set_xlabel('Probability')
    ax.set_title("Probability of Classes")
    
    plt.show()
 
    
    
    

check_sanity()
